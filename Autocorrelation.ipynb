# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysalearner1234/R-language121825/blob/main/Autocorrelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install if not already installed
install.packages("forecast")
install.packages("tseries")

# Load libraries
library(forecast)
library(tseries)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-723310569.py in <cell line: 0>()
#       1 # Install if not already installed
# ----> 2 install.packages("forecast")
#       3 install.packages("tseries")
#       4
#       5 # Load libraries
#
# NameError: name 'install' is not defined

# %%
# !apt-get install -y r-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# r-base is already the newest version (4.5.2-1.2204.0).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %%
# %%R
# Out:
# UsageError: Cell magic `%%R` not found.

# %%
# %%R
# install.packages("forecast")
# install.packages("tseries")
#
# library(forecast)
# library(tseries)
#
# # Load dataset
# data("AirPassengers")
# ts_data <- AirPassengers
#
# # ACF
# acf(ts_data, main="Autocorrelation Function (ACF)")
#
# # PACF
# pacf(ts_data, main="Partial Autocorrelation Function (PACF)")
# Out:
# UsageError: Cell magic `%%R` not found.

# %% [markdown]
# # Task
# The current Colab notebook is running a Python kernel, which is causing an error when trying to execute R code to install and load packages. To resolve this, you need to switch the notebook's runtime to R. After changing the runtime, re-run cell `3l_Jofe_mbFU` to successfully install and load the necessary R packages.

# %% [markdown]
# ## Identify current kernel
#
# ### Subtask:
# Determine if the notebook's active kernel is Python or R.

# %% [markdown]
# **Reasoning**:
# The previous code failed because `install.packages` is an R function being called in what appears to be a Python environment. To confirm the current kernel, I will use Python's `sys` module to identify the interpreter and thus the kernel type.

# %%
import sys
print(sys.version)

# Additionally, to provide a more direct answer, we can check for IPython specific attributes
# which are common in notebook environments like Colab.
# This helps confirm if it's a Python kernel, as opposed to an R kernel trying to run Python.

try:
    # Check if we are in an IPython environment (common for Jupyter/Colab Python kernels)
    ipython = get_ipython()
    if ipython is not None:
        print("Current kernel is likely Python (IPython environment detected).")
    else:
        print("Current kernel is Python (Non-IPython environment detected).")
except NameError:
    print("Could not confirm kernel type programmatically beyond Python version. Please check 'Runtime -> Change runtime type' in the Colab menu.")
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Current kernel is likely Python (IPython environment detected).

# %% [markdown]
# The output from the previous cell (`3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]\nCurrent kernel is likely Python (IPython environment detected).`) confirms that the current runtime type is **Python**.
#
# To visually confirm this, please navigate to **'Runtime'** in the Colab menu bar, then select **'Change runtime type'**. You will see that the 'Runtime type' is currently set to **Python 3**.

# %% [markdown]
# ## Switch to R runtime (if necessary)
#
# ### Subtask:
# If the current kernel is Python, instruct the user on how to change the Colab notebook's runtime to R to properly execute the R code.

# %% [markdown]
# It has been confirmed that the current Colab notebook is running a Python kernel. To proceed with the R code, you need to switch the runtime environment to R. Please follow these steps to change your Colab notebook's runtime:
#
# 1.  Navigate to 'Runtime' in the Colab menu bar (at the top of the page).
# 2.  Select 'Change runtime type'.
# 3.  In the 'Notebook settings' window, locate the 'Runtime type' dropdown menu.
# 4.  From the dropdown, select 'R'.
# 5.  Click the 'Save' button. This will restart the runtime.

# %% [markdown]
# ## Execute R code
#
# ### Subtask:
# Once the R runtime is active, re-execute cell `3l_Jofe_mbFU` to install and load the R packages.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# 1.  **What is the current kernel type of the Colab notebook?**
#     The current kernel type is Python (specifically, Python 3.12.12), and it is operating within an IPython environment.
# 2.  **How can the notebook's runtime be switched to R?**
#     To switch the runtime to R, navigate to 'Runtime' > 'Change runtime type' in the Colab menu, then select 'R' from the 'Runtime type' dropdown and click 'Save'.
#
# ### Data Analysis Key Findings
# *   The initial diagnostic confirmed that the notebook's active kernel is **Python**, identified by `sys.version` (Python 3.12.12) and the detection of an IPython environment.
# *   Clear, step-by-step instructions were provided to guide the user on how to change the Colab notebook's runtime from Python to **R**.
#
# ### Insights or Next Steps
# *   After successfully changing the runtime to R, the user should re-execute cell `3l_Jofe_mbFU` to install and load the necessary R packages, resolving the initial error.

# %%
data("AirPassengers")
ts_data <- AirPassengers

# View basic details
summary(ts_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-793694635.py in <cell line: 0>()
# ----> 1 data("AirPassengers")
#       2 ts_data <- AirPassengers
#       3
#       4 # View basic details
#       5 summary(ts_data)
#
# NameError: name 'data' is not defined

# %%
acf(ts_data,
    main = "Autocorrelation Function (ACF)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1414711716.py in <cell line: 0>()
# ----> 1 acf(ts_data,
#       2     main = "Autocorrelation Function (ACF)")
#
# NameError: name 'acf' is not defined

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.datasets import airpassengers

# Load dataset
data = airpassengers.load_pandas().data['value']

# Plot ACF
plot_acf(data, lags=40)
plt.show()

# Plot PACF
plot_pacf(data, lags=40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1222983064.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# ----> 3 from statsmodels.datasets import airpassengers
#       4
#       5 # Load dataset
#
# ImportError: cannot import name 'airpassengers' from 'statsmodels.datasets' (/usr/local/lib/python3.12/dist-packages/statsmodels/datasets/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# AirPassengers dataset (manually defined)
air_passengers = [
    112,118,132,129,121,135,148,148,136,119,104,118,
    115,126,141,135,125,149,170,170,158,133,114,140,
    145,150,178,163,172,178,199,199,184,162,146,166,
    171,180,193,181,183,218,230,242,209,191,172,194,
    196,196,236,235,229,243,264,272,237,211,180,201,
    204,188,235,227,234,264,302,293,259,229,203,229,
    242,233,267,269,270,315,364,347,312,274,237,278,
    284,277,317,313,318,374,413,405,355,306,271,306,
    315,301,356,348,355,422,465,467,404,347,305,336,
    340,318,362,348,363,435,491,505,404,359,310,337,
    360,342,406,396,420,472,548,559,463,407,362,405,
    417,391,419,461,472,535,622,606,508,461,390,432
]

# Convert to pandas Series
ts_data = pd.Series(air_passengers)

# Plot ACF
plot_acf(ts_data, lags=40)
plt.title("Autocorrelation Function (ACF)")
plt.show()

# Plot PACF
plot_pacf(ts_data, lags=40)
plt.title("Partial Autocorrelation Function (PACF)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Example time series data
data = [10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22]

# Convert to pandas Series
ts_data = pd.Series(data)

# Plot Autocorrelation Function
plot_acf(ts_data, lags=10)
plt.title("Autocorrelation (ACF)")
plt.xlabel("Lag")
plt.ylabel("Correlation")
plt.show()

# %%
# Example time series data
ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)

# Plot Autocorrelation
acf(ts_data,
    main = "Autocorrelation Function (ACF)",
    xlab = "Lag",
    ylab = "Correlation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2148814697.py in <cell line: 0>()
#       1 # Example time series data
# ----> 2 ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)
#       3
#       4 # Plot Autocorrelation
#       5 acf(ts_data,
#
# NameError: name 'c' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Example time series data (Python list)
ts_data = [10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22]

# Convert to pandas Series
ts_series = pd.Series(ts_data)

# Plot Autocorrelation Function
plot_acf(ts_series, lags=10)
plt.title("Autocorrelation Function (ACF)")
plt.xlabel("Lag")
plt.ylabel("Correlation")
plt.show()

# %% [markdown]
# # Task
# Change the Colab notebook's runtime to R, and then re-execute cell `3l_Jofe_mbFU` to install and load the R packages.

# %% [markdown]
# ## Identify current kernel
#
# ### Subtask:
# Determine if the notebook's active kernel is Python or R.

# %% [markdown]
# ## Switch to R runtime (if necessary)
#
# ### Subtask:
# If the current kernel is Python, instruct the user on how to change the Colab notebook's runtime to R to properly execute the R code.

# %% [markdown]
# ## Execute R code
#
# ### Subtask:
# Once the R runtime is active, re-execute cell `3l_Jofe_mbFU` to install and load the R packages.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The current runtime environment of the Colab notebook was identified as Python.
# *   Instructions for switching the Colab notebook's runtime to R were previously provided to the user.
#
# ### Insights or Next Steps
# *   The user needs to manually change the Colab notebook's runtime from Python to R as per the instructions already given.
# *   After changing the runtime, the user should re-execute cell `3l_Jofe_mbFU` to install and load the necessary R packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Example time series data
ts_data = [10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22]

# Convert to pandas Series
ts_series = pd.Series(ts_data)

# Plot Autocorrelation Function (ACF)
plot_acf(ts_series, lags=10)
plt.title("Autocorrelation Function (ACF)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

# Example time series data
ts_data = [10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22]

# Convert to pandas Series
ts_series = pd.Series(ts_data)

# Plot Partial Autocorrelation Function (PACF)
plot_pacf(ts_series, lags=5, method="ywm")
plt.title("Partial Autocorrelation Function (PACF)")
plt.xlabel("Lag")
plt.ylabel("Correlation")
plt.show()

# %%
# Example time series data
ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)

# Plot Partial Autocorrelation Function
pacf(ts_data,
     main = "Partial Autocorrelation Function (PACF)",
     xlab = "Lag",
     ylab = "Correlation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-196403805.py in <cell line: 0>()
#       1 # Example time series data
# ----> 2 ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)
#       3
#       4 # Plot Partial Autocorrelation Function
#       5 pacf(ts_data,
#
# NameError: name 'c' is not defined

# %%
# Example time series data
ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)

# Plot Partial Autocorrelation Function
pacf(ts_data,
     main = "Partial Autocorrelation Function (PACF)",
     xlab = "Lag",
     ylab = "Correlation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-196403805.py in <cell line: 0>()
#       1 # Example time series data
# ----> 2 ts_data <- c(10, 12, 13, 12, 14, 15, 16, 18, 17, 19, 20, 22)
#       3
#       4 # Plot Partial Autocorrelation Function
#       5 pacf(ts_data,
#
# NameError: name 'c' is not defined
